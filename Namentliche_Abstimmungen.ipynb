# %% [markdown]
# # Excel Dateien importieren

# %%
import pandas as pd
Abstimmung_1 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 1.xlsx")
Abstimmung_2 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 2.xlsx")
Abstimmung_3 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 3.xlsx")
Abstimmung_4 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 4.xlsx")
Abstimmung_5 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 5.xlsx")
Abstimmung_6 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 6.xlsx")
Abstimmung_7 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 7.xlsx")
Abstimmung_8 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 8.xlsx")
Abstimmung_9 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 9.xlsx")
Abstimmung_10 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 10.xlsx")
Abstimmung_11 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 11.xlsx")
Abstimmung_12 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 12.xlsx")
Abstimmung_13 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 13.xlsx")
Abstimmung_14 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 14.xlsx")
Abstimmung_15 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 15.xlsx")
Abstimmung_16 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 16.xlsx")
Abstimmung_17 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 17.xlsx")
Abstimmung_18 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 18.xlsx")
Abstimmung_19 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 19.xlsx")
Abstimmung_20 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 20.xlsx")
Abstimmung_21 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 21.xlsx")
Abstimmung_22 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 22.xlsx")
Abstimmung_23 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 23.xlsx")
Abstimmung_24 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 24.xlsx")
Abstimmung_25 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 25.xlsx")
Abstimmung_26 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 26.xlsx")
Abstimmung_27 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 27.xlsx")
Abstimmung_28 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 28.xlsx")
Abstimmung_29 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 29.xlsx")
Abstimmung_30 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 30.xlsx")
Abstimmung_31 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 31.xlsx")
Abstimmung_32 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 32.xlsx")
Abstimmung_33 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 33.xlsx")
Abstimmung_34 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 34.xlsx")
Abstimmung_35 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 35.xlsx")
Abstimmung_36 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 36.xlsx")
Abstimmung_37 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 37.xlsx")
Abstimmung_38 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 38.xlsx")
Abstimmung_39 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 39.xlsx")
Abstimmung_40 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 40.xlsx")
Abstimmung_41 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 41.xlsx")
Abstimmung_42 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 42.xlsx")
Abstimmung_43 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 43.xlsx")
Abstimmung_44 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 44.xlsx")
Abstimmung_45 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 45.xlsx")
Abstimmung_46 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 46.xlsx")
Abstimmung_47 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 47.xlsx")
Abstimmung_48 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 48.xlsx")
Abstimmung_49 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 49.xlsx")
Abstimmung_50 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 50.xlsx")
Abstimmung_51 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 51.xlsx")
Abstimmung_52 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 52.xlsx")
Abstimmung_53 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 53.xlsx")
Abstimmung_54 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 54.xlsx")
Abstimmung_55 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 55.xlsx")
Abstimmung_56 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 56.xlsx")
Abstimmung_57 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 57.xlsx")
Abstimmung_58 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 58.xlsx")
Abstimmung_59 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 59.xlsx")
Abstimmung_60 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 60.xlsx")
Abstimmung_61 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 61.xlsx")
Abstimmung_62 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 62.xlsx")
Abstimmung_63 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 63.xlsx")
Abstimmung_64 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 64.xlsx")
Abstimmung_65 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 65.xlsx")
Abstimmung_66 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 66.xlsx")
Abstimmung_67 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 67.xlsx")
Abstimmung_68 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 68.xlsx")
Abstimmung_69 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 69.xlsx")
Abstimmung_70 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 70.xlsx")
Abstimmung_71 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 71.xlsx")
Abstimmung_72 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 72.xlsx")
Abstimmung_73 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 73.xlsx")
Abstimmung_74 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 74.xlsx")
Abstimmung_75 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 75.xlsx")
Abstimmung_76 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 76.xlsx")
Abstimmung_77 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 77.xlsx")
Abstimmung_78 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 78.xlsx")
Abstimmung_79 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 79.xlsx")
Abstimmung_80 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 80.xlsx")
Abstimmung_81 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 81.xlsx")
Abstimmung_82 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 82.xlsx")
Abstimmung_83 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 83.xlsx")
Abstimmung_84 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 84.xlsx")
Abstimmung_85 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 85.xlsx")
Abstimmung_86 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 86.xlsx")
Abstimmung_87 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 87.xlsx")
Abstimmung_88 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 88.xlsx")
Abstimmung_89 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 89.xlsx")
Abstimmung_90 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 90.xlsx")
Abstimmung_91 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 91.xlsx")
Abstimmung_92 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 92.xlsx")
Abstimmung_93 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 93.xlsx")
Abstimmung_94 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 94.xlsx")
Abstimmung_95 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 95.xlsx")
Abstimmung_96 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 96.xlsx")
Abstimmung_97 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 97.xlsx")
Abstimmung_98 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 98.xlsx")
Abstimmung_99 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 99.xlsx")
Abstimmung_100 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 100.xlsx")
Abstimmung_101 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 101.xlsx")
Abstimmung_102 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 102.xlsx")
Abstimmung_103 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 103.xlsx")
Abstimmung_104 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 104.xlsx")
Abstimmung_105 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 105.xlsx")
Abstimmung_106 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 106.xlsx")
Abstimmung_107 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 107.xlsx")
Abstimmung_108 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 108.xlsx")
Abstimmung_109 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 109.xlsx")
Abstimmung_110 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 110.xlsx")
Abstimmung_111 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 111.xlsx")
Abstimmung_112 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 112.xlsx")
Abstimmung_113 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 113.xlsx")
Abstimmung_114 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 114.xlsx")
Abstimmung_115 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 115.xlsx")
Abstimmung_116 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 116.xlsx")
Abstimmung_117 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 117.xlsx")
Abstimmung_118 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 118.xlsx")
Abstimmung_119 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 119.xlsx")
Abstimmung_120 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 120.xlsx")
Abstimmung_121 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 121.xlsx")
Abstimmung_122 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 122.xlsx")
Abstimmung_123 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 123.xlsx")
Abstimmung_124 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 124.xlsx")
Abstimmung_125 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 125.xlsx")
Abstimmung_126 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 126.xlsx")
Abstimmung_127 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 127.xlsx")
Abstimmung_128 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 128.xlsx")
Abstimmung_129 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 129.xlsx")
Abstimmung_130 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 130.xlsx")
Abstimmung_131 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 131.xlsx")
Abstimmung_132 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 132.xlsx")
Abstimmung_133 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 133.xlsx")
Abstimmung_134 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 134.xlsx")
Abstimmung_135 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 135.xlsx")
Abstimmung_136 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 136.xlsx")
Abstimmung_137 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 137.xlsx")
Abstimmung_138 = pd.read_excel("/content/drive/MyDrive/Namentliche Abstimmungen/Abstimmung 138.xlsx")

# %%
dataframes = [globals()[f"Abstimmung_{i}"] for i in range(1, 139)]
combined_df = pd.concat(dataframes, ignore_index=True)
print(combined_df)
# Out:
#         Wahlperiode  Sitzungnr  Abstimmnr Fraktion/Gruppe             Name  \
# 0                20          3          1             SPD             Abdi
# 1                20          3          1             SPD        Ahmetovic
# 2                20          3          1             SPD  Alabali-Radovan
# 3                20          3          1             SPD           Andres
# 4                20          3          1             SPD            Annen
# ...             ...        ...        ...             ...              ...
# 101554           20        152          2    Fraktionslos           Ulrich
# 101555           20        152          2    Fraktionslos           Vogler
# 101556           20        152          2    Fraktionslos      Wagenknecht
# 101557           20        152          2    Fraktionslos          Wissler
# 101558           20        152          2    Fraktionslos             Witt
#
# ...

# %%
combined_df.to_excel("Namentliche_Abstimmungen_Rohdaten.xlsx", index = False)
from google.colab import files
files.download("Namentliche_Abstimmungen_Rohdaten.xlsx")

# %% [markdown]
# # Auswertung

# %%
# Group by deputy name and count the number of times each deputy did not vote
deputy_not_voted = combined_df.groupby('Bezeichnung')['nichtabgegeben'].sum().reset_index()

# Group by deputy name and party, and count the number of times each deputy did not vote for each party
deputy_party_not_voted = combined_df.groupby(['Bezeichnung', 'Fraktion/Gruppe'])['nichtabgegeben'].sum().reset_index()

# Merge the two results on the deputy name column
merged_df = pd.merge(deputy_not_voted, deputy_party_not_voted, on='Bezeichnung', suffixes=('_total', '_party'))

# Display the result
merged_df
# Out:
#              Bezeichnung  nichtabgegeben_total Fraktion/Gruppe  \
# 0    Achim Post (Minden)                    13             SPD
# 1         Adis Ahmetovic                     2             SPD
# 2      Agnieszka Brugger                     5         BÜ90/GR
# 3       Albert Rupprecht                    12         CDU/CSU
# 4       Albert Stegemann                    17         CDU/CSU
# ..                   ...                   ...             ...
# 803          Ye-One Rhie                     4             SPD
# 804        Yvonne Magwas                    10         CDU/CSU
# 805        Zaklin Nastic                    31      DIE LINKE.
# 806        Zaklin Nastic                    31    Fraktionslos
# 807            Zoe Mayer                    13         BÜ90/GR
#
#      nichtabgegeben_party
# 0                      13
# 1                       2
# 2                       5
# 3                      12
# 4                      17
# ..                    ...
# ...

# %%
merged_df.to_excel("Namentliche_Abstimmungen.xlsx", index = False)
from google.colab import files
files.download("Namentliche_Abstimmungen.xlsx")

# %%
combined_df
# Out:
#         Wahlperiode  Sitzungnr  Abstimmnr Fraktion/Gruppe             Name  \
# 0                20          3          1             SPD             Abdi
# 1                20          3          1             SPD        Ahmetovic
# 2                20          3          1             SPD  Alabali-Radovan
# 3                20          3          1             SPD           Andres
# 4                20          3          1             SPD            Annen
# ...             ...        ...        ...             ...              ...
# 101554           20        152          2    Fraktionslos           Ulrich
# 101555           20        152          2    Fraktionslos           Vogler
# 101556           20        152          2    Fraktionslos      Wagenknecht
# 101557           20        152          2    Fraktionslos          Wissler
# 101558           20        152          2    Fraktionslos             Witt
#
# ...

# %%
Fraktionen_abst = merged_df.groupby("Fraktion/Gruppe")["nichtabgegeben_party"].sum().reset_index()
Fraktionen_abst
# Out:
#   Fraktion/Gruppe  nichtabgegeben_party
# 0             AfD                  1714
# 1         BÜ90/GR                  1526
# 2         CDU/CSU                  3311
# 3      DIE LINKE.                   950
# 4             FDP                  1270
# 5    Fraktionslos                   292
# 6             SPD                  2575

# %%
Fraktionen_abst["Fraktionsgröße"] = [78,118,197,38,92,6,207]
Fraktionen_abst["Zahl der Abstimmungen"] = [138, 138, 138, 124, 138, 138, 138]
Fraktionen_abst
# Out:
#   Fraktion/Gruppe  nichtabgegeben_party  Fraktionsgröße  Zahl der Abstimmungen
# 0             AfD                  1714              78                    138
# 1         BÜ90/GR                  1526             118                    138
# 2         CDU/CSU                  3311             197                    138
# 3      DIE LINKE.                   950              38                    124
# 4             FDP                  1270              92                    138
# 5    Fraktionslos                   292               6                    138
# 6             SPD                  2575             207                    138

# %%
Fraktionen_abst["Fraktionsgröße_x_Abstimmungen"] = Fraktionen_abst["Fraktionsgröße"] * Fraktionen_abst["Zahl der Abstimmungen"]
Fraktionen_abst["nicht abgestimmt in Prozent"] = Fraktionen_abst["nichtabgegeben_party"] / Fraktionen_abst["Fraktionsgröße_x_Abstimmungen"] * 100
Fraktionen_abst
# Out:
#   Fraktion/Gruppe  nichtabgegeben_party  Fraktionsgröße  \
# 0             AfD                  1714              78
# 1         BÜ90/GR                  1526             118
# 2         CDU/CSU                  3311             197
# 3      DIE LINKE.                   950              38
# 4             FDP                  1270              92
# 5    Fraktionslos                   292               6
# 6             SPD                  2575             207
#
#    Zahl der Abstimmungen  Fraktionsgröße_x_Abstimmungen  \
# 0                    138                          10764
# 1                    138                          16284
# 2                    138                          27186
# 3                    124                           4712
# 4                    138                          12696
# 5                    138                            828
# 6                    138                          28566
#
#    nicht abgestimmt in Prozent
# ...

# %%
Abgeordnete_abst = combined_df.groupby("Bezeichnung")["nichtabgegeben"].sum()
Abgeordnete_abst
# Out:
# Bezeichnung
# Achim Post (Minden)    13
# Adis Ahmetovic          2
# Agnieszka Brugger       5
# Albert Rupprecht       12
# Albert Stegemann       17
#                        ..
# Yasmin Fahimi           8
# Ye-One Rhie             4
# Yvonne Magwas          10
# Zaklin Nastic          31
# Zoe Mayer              13
# Name: nichtabgegeben, Length: 765, dtype: int64

# %%
merged_df.to_excel("Namentliche_Abstimmungen.xlsx", index = False)
from google.colab import files
files.download("Namentliche_Abstimmungen.xlsx")

# %% [markdown]
# # Mit entschuldigt/unentschuldigt

# %%
df_absences = pd.read_excel("/content/drive/MyDrive/Projektarbeit 2/Fehlzeiten_final_korrigiert (5).xlsx")

# Assuming df_absences is your dataframe containing excused absences
# and df_voting is your dataframe containing voting records

# Step 1: Calculate the total number of times each member didn't vote in df_voting
member_non_votes = combined_df.groupby(['Bezeichnung',"Fraktion/Gruppe"])['nichtabgegeben'].sum().reset_index()

# Step 2: Merge df_absences with df_voting to get information on absences for each member
merged_df_fz = pd.merge(combined_df, df_absences, how='left', left_on=['Bezeichnung', 'Sitzungnr'], right_on=['Full Name', 'Sitzungsnummer'])

# Step 3: Calculate the number of times each member didn't vote when they weren't excused
member_non_excused_votes = merged_df_fz[merged_df_fz['Full Name'].isnull()].groupby(['Bezeichnung',"Fraktion/Gruppe"])['nichtabgegeben'].sum().reset_index()
member_non_excused_votes.rename(columns={'nichtabgegeben': 'unentschuldigt nicht abgestimmt'}, inplace=True)

# Step 4: Merge the results with the total number of non-votes for each member
result_df = pd.merge(member_non_votes, member_non_excused_votes, on='Bezeichnung', how='left').fillna(0)

# Display the result dataframe
result_df
# Out:
#              Bezeichnung Fraktion/Gruppe_x  nichtabgegeben Fraktion/Gruppe_y  \
# 0    Achim Post (Minden)               SPD              13               SPD
# 1         Adis Ahmetovic               SPD               2               SPD
# 2      Agnieszka Brugger           BÜ90/GR               5           BÜ90/GR
# 3       Albert Rupprecht           CDU/CSU              12           CDU/CSU
# 4       Albert Stegemann           CDU/CSU              17           CDU/CSU
# ..                   ...               ...             ...               ...
# 887        Zaklin Nastic        DIE LINKE.              30        DIE LINKE.
# 888        Zaklin Nastic        DIE LINKE.              30      Fraktionslos
# 889        Zaklin Nastic      Fraktionslos               1        DIE LINKE.
# 890        Zaklin Nastic      Fraktionslos               1      Fraktionslos
# 891            Zoe Mayer           BÜ90/GR              13           BÜ90/GR
#
#      unentschuldigt nicht abgestimmt
# ...

# %%
df_absences
# Out:
#      Last Name   First Name                   Party       Datum  \
# 0       Bareiß       Thomas                 CDU/CSU  02/02/2024
# 1      Beckamp        Roger                     AfD  02/02/2024
# 2        Beyer        Peter                 CDU/CSU  02/02/2024
# 3     Bollmann       Gereon                     AfD  02/02/2024
# 4        Braun       Jürgen                     AfD  02/02/2024
# ...        ...          ...                     ...         ...
# 7589   Lehmann       Sylvia                     SPD  10/26/2021
# 7590    Nestle   Dr. Ingrid  BÜNDNIS 90/ DIE GRÜNEN  10/26/2021
# 7591    Ortleb  Josephine *                     SPD  10/26/2021
# 7592      Pohl       Jürgen                     AfD  10/26/2021
# 7593      Witt          Uwe                     AfD  10/26/2021
#
#               Full Name  Mutterschutz  Pattern_In_Full_Name  Sitzungsnummer
# 0         Thomas Bareiß             0                  True             152
# ...

# %%
import pandas as pd

# Assuming df_absences is your dataframe containing excused absences
# and df_voting is your dataframe containing voting records

# Step 1: Duplicate rows for deputies who switched parties
duplicates = pd.concat([df_absences[df_absences.duplicated(subset=['Full Name'], keep=False)], combined_df[combined_df.duplicated(subset=['Bezeichnung'], keep=False)]])

# Step 2: Update party information for each duplicate row
party_mapping = df_absences.groupby('Full Name')['Party'].nunique().reset_index()
party_mapping = party_mapping[party_mapping['Party'] > 1]
party_mapping = pd.merge(party_mapping, df_absences[['Full Name', 'Party']], on='Full Name', how='left')
party_mapping = party_mapping.drop_duplicates(subset=['Full Name', 'Party'])

duplicates = pd.merge(duplicates, party_mapping, on='Full Name', how='left')

# Step 3: Calculate excused and non-excused absences separately for each party
result_df = duplicates.groupby(['Full Name', 'Party'])[['Did Not Vote']].sum().reset_index()

# Display the result dataframe
print(result_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-585a7f90cbfa> in <cell line: 13>()
#      11 party_mapping = party_mapping[party_mapping['Party'] > 1]
#      12 party_mapping = pd.merge(party_mapping, df_absences[['Full Name', 'Party']], on='Full Name', how='left')
# ---> 13 party_mapping = party_mapping.drop_duplicates(subset=['Full Name', 'Party'])
#      14
#      15 duplicates = pd.merge(duplicates, party_mapping, on='Full Name', how='left')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
Fraktionen_abst_ent = result_df.groupby("Fraktion/Gruppe")["nichtabgegeben","unentschuldigt nicht abgestimmt"].sum().reset_index()
Fraktionen_abst_ent

# %%
Fraktionen_abst_ent["Fraktionsgröße"] = [78,118,197,38,92,6,207]
Fraktionen_abst_ent["Zahl der Abstimmungen"] = [138, 138, 138, 124, 138, 138, 138]
Fraktionen_abst_ent

# %%
Fraktionen_abst_ent["Fraktionsgröße_x_Abstimmungen"] = Fraktionen_abst_ent["Fraktionsgröße"] * Fraktionen_abst_ent["Zahl der Abstimmungen"]
Fraktionen_abst_ent["nicht abgestimmt in Prozent"] = Fraktionen_abst_ent["nichtabgegeben"] / Fraktionen_abst_ent["Fraktionsgröße_x_Abstimmungen"] * 100
Fraktionen_abst_ent["unentschuldigt nicht abgestimmt Prozent"] = Fraktionen_abst_ent["unentschuldigt nicht abgestimmt"] / Fraktionen_abst_ent["Fraktionsgröße_x_Abstimmungen"] * 100
Fraktionen_abst_ent

# %% [markdown]
# # Ab hier nicht mehr wichtig

# %%
combined_df_unique = combined_df.drop_duplicates(subset="Bezeichnung")

# %%
Abgeordnete_abst_df2 = pd.merge(left = Abgeordnete_abst_df,
                          right = combined_df_unique,
                          left_on = 'Bezeichnung',
                          right_on = 'Bezeichnung',
                          how = 'inner')

# %%
Abgeordnete_abst_df2

# %%
Abgeordnete_abst_df3 = Abgeordnete_abst_df2.drop(columns=["Wahlperiode","Sitzungnr","Abstimmnr","Name","Vorname","Titel","ja","nein","Enthaltung","ungültig","nichtabgegeben_y","Bemerkung"])
Abgeordnete_abst_df3
# Überprüfen ob Partei oder fraktionslos

# %%
Fraktionen_om = Abgeordnete_final.groupby("Party")["Fehlzeiten ohne Mutterschutz"].sum().reset_index()
Fraktionen_om

# %%
Abstimmungen_unique = combined_df.drop_duplicates(subset="Fraktion/Gruppe")

# %%
Abstimmungen = pd.merge(left = Abgeordnete_abst_df,
                          right = Abstimmungen_unique,
                          left_on = 'Bezeichnung',
                          right_on = 'Bezeichnung',
                          how = 'inner')

# %%
Abstimmungen

# %%
Abstimmungen = Abstimmungen.drop(columns=["Wahlperiode","Sitzungnr","Abstimmnr","Name","Vorname","Titel","ja","nein","Enthaltung","ungültig","Bemerkung"])

# %%
Abstimmungen = Abstimmungen.drop(columns=["nichtabgegeben_y"])

# %%
Abstimmungen

# %%
Abstimmungen_abst = Abstimmungen.groupby("Bezeichnung")["nichtabgegeben_x"].sum()
Abstimmungen_abst

# %%
Abgeordnete_abst_df.to_excel("Nicht_abgestimmt_Abgeordnete.xlsx", index = False)
from google.colab import files
files.download("Nicht_abgestimmt_Abgeordnete.xlsx")

# %%
Fraktionen_abst = combined_df.groupby("Fraktion/Gruppe")["nichtabgegeben"].sum()

# %%
Fraktionen_abst_df = Fraktionen_abst.reset_index()
Fraktionen_abst_df

# %%
Fraktionen_abst_df["Fraktionsgröße"] = [78,118,197,38,92,6,207]
Fraktionen_abst_df

# %%
Fraktionen_abst_df["Abgeordnete_x_Sitzungen"] = Fraktionen_abst_df["Fraktionsgröße"] * 152

# %%
Fraktionen_abst_df["Nicht_abgestimmt_in_Prozent"] = Fraktionen_abst_df["nichtabgegeben"] / Fraktionen_abst_df["Abgeordnete_x_Sitzungen"] * 100
Fraktionen_abst_df

# %%
Abgeordnete_abst_df = Abgeordnete_abst.reset_index()
Abgeordnete_abst_df

# %%
Fraktionen_om = Abgeordnete_final.groupby("Party")["Fehlzeiten ohne Mutterschutz"].sum().reset_index()
Fraktionen_om
